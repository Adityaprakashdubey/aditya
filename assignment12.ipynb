# %%
1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?
Ans: For PdfFileReader() file objects should be opened in rb -> read binary mode,
    Whereas for PdfFileWriter() file objects
    should be opened in wb -> write binary mode.

# %%
2. From a PdfFileReader object, how do you get a Page object for page 5?
ans =  getpage(page_no)
# Out:
#   File "C:\Users\91941\AppData\Local\Temp/ipykernel_12980/4170554214.py", line 1
#     2. From a PdfFileReader object, how do you get a Page object for page 5?
#        ^
# SyntaxError: invalid syntax

# %%
from PyPDF2 import PdfFileReader
pdf_reader = PdfFileReader(r"C:\Users\91941\Downloads\machine_learning_tutorial.pdf")
print(pdf_reader.getNumPages())
#for i in pdf_reader.getNumPages():
print(pdf_reader.getPage(1))
# Out:
# 35
# {'/Type': '/Page', '/Parent': IndirectObject(2, 0, 2116993894912), '/Resources': {'/ExtGState': {'/GS5': IndirectObject(5, 0, 2116993894912), '/GS8': IndirectObject(8, 0, 2116993894912)}, '/Font': {'/F1': IndirectObject(6, 0, 2116993894912), '/F2': IndirectObject(14, 0, 2116993894912), '/F3': IndirectObject(19, 0, 2116993894912), '/F4': IndirectObject(21, 0, 2116993894912), '/F5': IndirectObject(26, 0, 2116993894912)}, '/XObject': {'/Image9': IndirectObject(9, 0, 2116993894912)}, '/ProcSet': ['/PDF', '/Text', '/ImageB', '/ImageC', '/ImageI']}, '/Annots': [IndirectObject(28, 0, 2116993894912)], '/MediaBox': [0, 0, 595.32, 841.92], '/Contents': IndirectObject(13, 0, 2116993894912), '/Group': {'/Type': '/Group', '/S': '/Transparency', '/CS': '/DeviceRGB'}, '/Tabs': '/S', '/StructParents': 1}

# %%
# !pip install PyPDF2

# %%
3. What PdfFileReader variable stores the number of pages 
in the PDF document?

ans= getnumpages()

# %%
4. If a PdfFileReader object’s PDF is encrypted with the password swordfish,
what must you do before you can obtain Page objects from it?
#ans= If a PdfFileReader object’s PDF is encrypted with the password
swordfish and you're not aware of it.
first read the Pdf using the PdfFileReader Class.
PdfFileReader class provides a attribute called isEncrypted to check whether a pdf is encrypted or not. the method returns true if a pdf is encrypted and vice versa.
if pdf is encrypted use the decrypt()
method provided by PdfFileReader class first then try to read the contents/pages of the pdf,
else PyPDF2 will raise the following error PyPDF2.utils.PdfReadError: file has not been decrypted

# %%
from PyPDF2 import PdfFileReader
file = PdfFileReader(r"C:\Users\91941\Downloads\machine_learning_tutorial.pdf")
if file.is_encrypted:
    file.decrypt("swordfish")
for i in file.pages:
    print(i.extract_text())
# Out:
#   i
#
#
#
#   i
#
# About the T utorial
# Today’s Artificial Intelligence (AI) has far surpassed the hype of blockchain and quantum
# computing. The developers now take advantage of this in creating new Machine Learning
# models and to re -train the existing models for better performance and results.
# This tutorial will give an introduction to machine learning and its implementation in
# Artificial Intelligence.
# Audience
# This tutorial has been prepared for professionals aspiring to learn the complete picture of
# machine learning and artificial intelligence .
# This tutorial caters the learning needs of  both the novice learners and experts , to help
# them understand the concepts and implementation of artificial intelligence .
#
# Prerequisites
# The learners of this tutorial are expected to know the basics of Python pr ogramming.
# Besides, they need to have a solid understanding of  computer programing and
# fundamentals.
# ...

# %%
5. What methods do you use to rotate a page?
ans
rotateClockWise() -> For Clockwise rotation
rotateCounterClockWise() -> For Counter Clockwise rotation

# %%
6. What is the difference between a Run object and a Paragraph object?
ans
Paragraph Object : A document contains multiple paragraphs.
    A paragraph begins on a new line and contains multiple runs.
    The Document object contains a list of Paragraph objects for
    the paragraphs in the document. ...
Run Objects : Runs are contiguous groups of characters within
    a paragraph with the same style.

# %%
# !pip install docx
# Out:
# ...
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53924 sha256=031d9e39df8d7a754c592fd9a355b1d9e4aa0b352e4f7527dad422b6a53e5f16
#   Stored in directory: c:\users\91941\appdata\local\pip\cache\wheels\0f\8e\9d\7003eed35a84cf960876aae6bdf60d02041ddfcca66eceee94
# Successfully built docx
# ...

# %%
#7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a
#variable named doc?

##ANS

from docx import Document
doc = Document(r"C:\Users\91941\Downloads\1809131011aditya prakash dubey.docx")
print(doc.paragraphs)
for i in doc.paragraphs:
    print(i.text)
# Out:
# [<docx.text.paragraph.Paragraph object at 0x000001ECE8B99580>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B994F0>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B99490>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B996D0>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B99730>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B99640>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B996A0>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B99820>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B99850>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B997C0>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B998E0>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B999D0>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B99A30>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B99940>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B99BE0>, <docx.text.paragraph.Paragraph object at 0x000001ECE8B99B80>, <docx
# ...

# %%
#8. What type of object has bold, underline, italic, strike, and outline variables?
#ans
#  Run

# %%
9. What is the difference between False, True, and None for the bold variable?

ans

#bold = True  # Style Set to Bold
#bold = False # Style Not Set to Bold
#bold = None # Style is Not Applicable

# %%
pip install python-docx
# Out:
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184508 sha256=fafa50f46b14db1d6e78ef160e9830c185a76997ece4851b32a82f4379ca79c1
#   Stored in directory: c:\users\91941\appdata\local\pip\cache\wheels\83\8b\7c\09ae60c42c7ba4ed2dddaf2b8b9186cb105255856d6ed3dba5
# Successfully built python-docx
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#10. How do you create a Document object for a new Word document?
from docx import Document
doc = Document()
doc.add_paragraph("hii evryone")
doc.save("mymade.docx")

# %%
#11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?
from docx import Document
doc = Document()
doc.add_paragraph('Hello, there!')
doc.save('hello.docx')
